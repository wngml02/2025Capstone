# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/github_
# Out:
# /content/drive/MyDrive/github_

# %%
from getpass import getpass
import os

token = getpass("Enter your GitHub PAT: ")
os.environ['GITHUB_TOKEN'] = token
# Out:
# Enter your GitHub PAT: ··········

# %%
# !git config --global --unset credential.helper
# !rm -rf ~/.git-credentials

# %%
# !git clone https://wngml02:$GITHUB_TOKEN@github.com/wngml02/2025Capstone.git
# Out:
# Cloning into '2025Capstone'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
cd /content/drive/MyDrive/github_/2025Capstone
# Out:
# /content/drive/MyDrive/github_/2025Capstone

# %%
# !git config --global user.email 'wngml021211@gmail.com'
# !git config --global user.name 'wngml02'

# %%
# %cd /content/drive/MyDrive/github_/2025Capstone
# !git add .
# Out:
# /content/drive/MyDrive/github_/2025Capstone

# %%
# !git commit -m '코랩-깃허브 연동'
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %%
# !ls /content/drive/MyDrive/github_/2025Capstone
# Out:
# README.md

# %%
import ipynbname
print(ipynbname.name())
# Out:
# fileId=1aXgd63PRszRA_WuXD2mAa4XrQRXuCrC0

# %%
import shutil

# 실제 파일 이름으로 바꿔줘야 해!
shutil.copy('/content/drive/MyDrive/github_/2025Capstone/real_imag_denoise.ipynb', '/content/drive/MyDrive/github_/2025Capstone/real_imag.ipynb')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-77-e83f52426b3f> in <cell line: 0>()
#       2
#       3 # 실제 파일 이름으로 바꿔줘야 해!
# ----> 4 shutil.copy('/content/drive/MyDrive/github_/2025Capstone/real_imag_denoise.ipynb', '/content/drive/MyDrive/github_/2025Capstone/real_imag.ipynb')
#
# /usr/lib/python3.11/shutil.py in copy(src, dst, follow_symlinks)
#     429     if os.path.isdir(dst):
#     430         dst = os.path.join(dst, os.path.basename(src))
# --> 431     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     432     copymode(src, dst, follow_symlinks=follow_symlinks)
#     433     return dst
#
# /usr/lib/python3.11/shutil.py in copyfile(src, dst, follow_symlinks)
#     254         os.symlink(os.readlink(src), dst)
#     255     else:
# --> 256         with open(src, 'rb') as fsrc:
#     257             try:
# ...
