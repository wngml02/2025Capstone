# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/github_
# Out:
# /content/drive/MyDrive/github_

# %%
from getpass import getpass
import os

token = getpass("Enter your GitHub PAT: ")
os.environ['GITHUB_TOKEN'] = token
# Out:
# Enter your GitHub PAT: ··········

# %%
# !git config --global user.email 'wngml021211@gmail.com'
# !git config --global user.name 'wngml02'

# %%
# !git add .
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !ls /content/drive/MyDrive/github_/2025Capstone
# Out:
# README.md  real_imag_denoise.ipynb  real_imag.ipynb

# %%
# !git config --global user.name "wngml02"
# !git config --global user.email "wngml021211@gamil.com"

# !git add .
# !git commit -m "Upload notebook from Colab"
# !git push origin main
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
